# %% [markdown]
# <a href="https://colab.research.google.com/github/Codenid/UTEC_2025_PROGRAMACION_101/blob/main/PRACTICA_2/Examen_4_Pandas_Winston_Flores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pregunta 1:

# %% [markdown]
# 1. Carga diabetes.csv en un DataFrame df_diabetes.

# %%
import pandas as pd
# 1. Carga diabetes.csv en un DataFrame.
df_diabetes = pd.read_csv('diabetes.csv')

# %% [markdown]
# 2. Muestra las 5 primeras filas.

# %%
print("Las 5 primeras filas de df_diabetes:")
print(df_diabetes.head())
# Out:
# Las 5 primeras filas de df_diabetes:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 3. Imprime el número total de filas, columnas y el tipo de cada columna.

# %%
print("\nInformación de df_diabetes:")
print(f"Número de filas: {df_diabetes.shape[0]}")
print(f"Número de columnas: {df_diabetes.shape[1]}")
print("\nTipos de datos de cada columna:")
print(df_diabetes.dtypes)
# Out:
# Información de df_diabetes:
# Número de filas: 768
# Número de columnas: 9
#
# Tipos de datos de cada columna:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# 4. Convierte la columna Outcome a tipo categórico y verifica el cambio imprimiendo la información del
# DataFrame (df_diabetes.info()).

# %%
# 4. Convertir la columna Outcome a tipo categórico
df_diabetes['Outcome'] = df_diabetes['Outcome'].astype('category')
print("\nInformación de df_diabetes después de convertir 'Outcome' a categórica:")
df_diabetes.info()
# Out:
# Información de df_diabetes después de convertir 'Outcome' a categórica:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB

# %% [markdown]
# # Pregunta 2:

# %% [markdown]
# 1. Crea un DataFrame df_filtrado con todas las filas de df_diabetes donde Glucose > 120.

# %%
# 1. DataFrame df_filtrado donde Glucose > 120.
df_filtrado = df_diabetes[df_diabetes['Glucose'] > 120]

# %% [markdown]
# 2. Agrega a df_filtrado una columna BMI_Category que clasifique el BMI así:
# *   "Bajo" si BMI < 18.5
# *   "Normal" si 18.5 ≤ BMI < 25
# *   "Sobrepeso" si 25 ≤ BMI < 30
# *   "Obeso" si BMI ≥ 30

# %%
df_filtrado['BMI_Category'] = df_filtrado['BMI'].apply(lambda bmi: "Bajo" if bmi < 18.5 else ("Normal" if 18.5 <= bmi < 25 else ("Sobrepeso" if 25 <= bmi < 30 else "Obeso")))
# Out:
# /tmp/ipython-input-9-413803291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['BMI_Category'] = df_filtrado['BMI'].apply(lambda bmi: "Bajo" if bmi < 18.5 else ("Normal" if 18.5 <= bmi < 25 else ("Sobrepeso" if 25 <= bmi < 30 else "Obeso")))

# %% [markdown]
# 3. Muestra las primeras 5 filas de df_filtrado con la nueva columna incluida.

# %%
df_filtrado.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age Outcome BMI_Category
# 0                     0.627   50       1        Obeso
# 2                     0.672   32       1       Normal
# 4                     2.288   33       1        Obeso
# 8                     0.158   53       1        Obeso
# 9                     0.232   54       1         Bajo

# %% [markdown]
# # Pregunta 3:

# %% [markdown]
# 1. Carga age_groups.csv en un DataFrame df_age_groups.

# %%
# 1. Carga age_groups.csv
df_age_groups = pd.read_csv('age_groups.csv')

# %% [markdown]
# 2. Haz un merge de df_diabetes con df_age_groups por la columna Age. El resultado se llamará df_combinado. Debe ser un left merge para mantener todas las filas de df_diabetes.

# %%
# 2. Merge de df_diabetes con df_age_groups por la columna Age
df_combinado = pd.merge(df_diabetes, df_age_groups, on='Age', how='left')

# %% [markdown]
# 3. Muestra las 5 primeras filas de df_combinado para verificar que la columna AgeGroup se haya agregado correctamente.

# %%
df_combinado.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age Outcome AgeGroup
# 0                     0.627   50       1   Adulto
# 1                     0.351   31       0   Adulto
# 2                     0.672   32       1   Adulto
# 3                     0.167   21       0    Joven
# 4                     2.288   33       1   Adulto

# %% [markdown]
# # Pregunta 4:

# %% [markdown]
# 1. Agrupa df_combinado por AgeGroup.

# %%
# 1. Agrupar df_combinado por AgeGroup.
grouped_data = df_combinado.groupby(['AgeGroup'])

# %% [markdown]
# 2. Calcula el promedio de Glucose y el promedio de BMI para cada grupo de edad.

# %%
grouped_data = df_combinado.groupby(['AgeGroup']).agg({
                            'Glucose': 'mean',
                            'BMI': 'mean'})

# %% [markdown]
# 3. Ordena el resultado por el promedio de Glucose de mayor a menor.

# %%
sorted_grouped_data = grouped_data.sort_values(by='Glucose', ascending=False)

# %% [markdown]
# 4. Muestra el DataFrame resultante.

# %%
sorted_grouped_data
# Out:
#                  Glucose        BMI
# AgeGroup
# Adulto_Mayor  139.679012  30.211111
# Adulto        125.637037  33.562593
# Joven         114.175060  31.322062

# %% [markdown]
# # Pregunta 5:

# %% [markdown]
# 1. A partir de df_combinado, filtra las filas donde AgeGroup = "Adulto" y Outcome = 1 (casos positivos de diabetes en adultos).

# %%
# 1. En df_combinado filtrar casos positivos de diabetes en adultos
adults_with_diabetes = df_combinado[(df_combinado['AgeGroup'] == 'Adulto') & (df_combinado['Outcome'] == 1)]

# %% [markdown]
# 2. De este subconjunto, selecciona los 5 registros con el mayor valor de BMI.

# %%
top_5_bmi_adults_diabetes = adults_with_diabetes.nlargest(5, 'BMI')
top_5_bmi_adults_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 193           11      135              0              0        0  52.3
# 155            7      152             88             44        0  50.0
# 99             1      122             90             51      220  49.7
# 84             5      137            108              0        0  48.8
# 378            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age Outcome AgeGroup
# 193                     0.578   40       1   Adulto
# 155                     0.337   36       1   Adulto
# 99                      0.325   31       1   Adulto
# 84                      0.227   37       1   Adulto
# 378                     0.238   32       1   Adulto

# %% [markdown]
# 3. Muestra únicamente las columnas Age, Glucose, BMI, DiabetesPedigreeFunction, ordenadas por BMI de mayor a menor.

# %%
top_5_bmi_adults_diabetes[['Age', 'Glucose', 'BMI', 'DiabetesPedigreeFunction']].sort_values(by='BMI', ascending=False)
# Out:
#      Age  Glucose   BMI  DiabetesPedigreeFunction
# 193   40      135  52.3                     0.578
# 155   36      152  50.0                     0.337
# 99    31      122  49.7                     0.325
# 84    37      137  48.8                     0.227
# 378   32      156  48.3                     0.238

# %% [markdown]
# # Pregunta 6:

# %% [markdown]
# 1. Usando df_combinado, crea una tabla pivote que tenga:
# *   Índice: AgeGroup
# *   Columnas: Outcome
# *   Valores: promedio de Glucose y BMI
# 2. La pivot table debe mostrar el promedio de Glucose y BMI por combinación de AgeGroup y Outcome.

# %%
pivot_table = df_combinado.pivot_table(index='AgeGroup', columns='Outcome', values=['Glucose', 'BMI'], aggfunc='mean')
pivot_table
# Out:
# /tmp/ipython-input-37-849531277.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df_combinado.pivot_table(index='AgeGroup', columns='Outcome', values=['Glucose', 'BMI'], aggfunc='mean')
#                     BMI                Glucose
# Outcome               0          1           0           1
# AgeGroup
# Adulto        31.923077  35.085000  111.830769  138.457143
# Adulto_Mayor  28.413953  32.244737  127.209302  153.789474
# Joven         29.909174  36.455556  106.978593  140.322222

# %% [markdown]
# 3. De la tabla resultante, filtra y muestra únicamente las filas (AgeGroups) donde el promedio de BMI para cualquiera de los valores de Outcome sea mayor a 30.

# %%
filtered_pivot_table = pivot_table[
    (pivot_table[('BMI', 0)] > 30) | (pivot_table[('BMI', 1)] > 30)
]

# %% [markdown]
# 4. Muestra el DataFrame resultante.

# %%
filtered_pivot_table
# Out:
#                     BMI                Glucose
# Outcome               0          1           0           1
# AgeGroup
# Adulto        31.923077  35.085000  111.830769  138.457143
# Adulto_Mayor  28.413953  32.244737  127.209302  153.789474
# Joven         29.909174  36.455556  106.978593  140.322222
